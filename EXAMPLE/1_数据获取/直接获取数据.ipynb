# %% [markdown]
# # QUANTAXIS 从web获取数据教程

# %% [markdown]
# 核心函数 QA_fetch_get_xxxxxx(数据来源,代码,日期/时间参数...)

# %% [markdown]
# ## 股票数据

# %%
import QUANTAXIS as QA

# %% [markdown]
# ### 1. 股票列表

# %%
QA.QA_fetch_get_stock_list('tdx')
# Out:
#               code  volunit  decimal_point  name    pre_close sse       sec
# code   sse
# 000001 sz   000001      100              2  平安银行   568.002500  sz  stock_cn
# 000002 sz   000002      100              2  万 科Ａ    23.549999  sz  stock_cn
# 000004 sz   000004      100              2  国农科技    17.400000  sz  stock_cn
# 000005 sz   000005      100              2  世纪星源  4034.005625  sz  stock_cn
# 000006 sz   000006      100              2  深振业Ａ     5.390000  sz  stock_cn
# 000007 sz   000007      100              2   全新好  1176.037500  sz  stock_cn
# 000008 sz   000008      100              2  神州高铁     4.220000  sz  stock_cn
# 000009 sz   000009      100              2  中国宝安     4.590000  sz  stock_cn
# 000010 sz   000010      100              2  美丽生态     4.600000  sz  stock_cn
# 000011 sz   000011      100              2  深物业A   952.012500  sz  stock_cn
# 000012 sz   000012      100              2  南 玻Ａ     4.970000  sz  stock_cn
# ...

# %% [markdown]
# ### 2.股票日线

# %%
QA.QA_fetch_get_stock_day('tdx','000001','2018-08-01','2018-08-10',if_fq='bfq')
# Out:
#             open  close  high   low       vol       amount        date  \
# date
# 2018-08-01  9.42   9.15  9.50  9.11  814081.0  759282240.0  2018-08-01
# 2018-08-02  9.13   8.94  9.15  8.88  931401.0  839272256.0  2018-08-02
# 2018-08-03  8.93   8.91  9.10  8.91  476546.0  428641536.0  2018-08-03
# 2018-08-06  8.94   8.94  9.11  8.89  554010.0  497906688.0  2018-08-06
# 2018-08-07  8.96   9.17  9.17  8.88  690423.0  624359680.0  2018-08-07
# 2018-08-08  9.16   9.05  9.16  9.04  578953.0  527526976.0  2018-08-08
# 2018-08-09  9.04   9.29  9.35  9.02  806783.0  746469824.0  2018-08-09
# 2018-08-10  9.30   9.23  9.32  9.16  424168.0  391366336.0  2018-08-10
#
#               code    date_stamp
# date
# 2018-08-01  000001  1.533053e+09
# 2018-08-02  000001  1.533139e+09
# 2018-08-03  000001  1.533226e+09
# 2018-08-06  000001  1.533485e+09
# 2018-08-07  000001  1.533571e+09
# 2018-08-08  000001  1.533658e+09
# 2018-08-09  000001  1.533744e+09
# 2018-08-10  000001  1.533830e+09

# %% [markdown]
# ### 3.股票分钟线

# %%
QA.QA_fetch_get_stock_min('tdx','000001','2018-08-30 09:30:00','2018-08-31 15:00:00')
# Out:
#                       open  close   high    low           vol        amount  \
# datetime
# 2018-08-30 09:31:00  10.27  10.28  10.28  10.26  1.520400e+06  1.561075e+07
# 2018-08-30 09:32:00  10.28  10.27  10.29  10.27  4.093000e+05  4.206112e+06
# 2018-08-30 09:33:00  10.27  10.31  10.32  10.26  9.171000e+05  9.434675e+06
# 2018-08-30 09:34:00  10.32  10.32  10.35  10.32  1.353300e+06  1.398551e+07
# 2018-08-30 09:35:00  10.33  10.32  10.33  10.30  1.455900e+06  1.502392e+07
# 2018-08-30 09:36:00  10.32  10.30  10.32  10.30  6.024000e+05  6.209240e+06
# 2018-08-30 09:37:00  10.30  10.30  10.32  10.29  1.106300e+06  1.140471e+07
# 2018-08-30 09:38:00  10.32  10.31  10.32  10.29  1.277900e+06  1.317305e+07
# 2018-08-30 09:39:00  10.30  10.28  10.31  10.28  6.833000e+05  7.029922e+06
# 2018-08-30 09:40:00  10.28  10.28  10.29  10.27  3.393000e+05  3.487379e+06
# 2018-08-30 09:41:00  10.28  10.30  10.30  10.28  6.424000e+05  6.612979e+06
# ...

# %% [markdown]
# ### 4. 股票分笔数据
