# %%
import QUANTAXIS as QA

# %%
user = QA.QA_User(username='admin', password='admin')

# %%
port = user.new_portfolio('test_newAccounts2')

# %%
for ux in range(0, 100):
    ac = port.new_account('ac_{}'.format(ux), market_type='future_cn')
    print(ac)
    ac.generate_randomtrade('RBL8', '2019-12-01', '2020-01-10', 'day')
    ac.save()
# Out:
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_0 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -2
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_1 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -3
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_2 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -2
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_3 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_4 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_5 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 3
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_6 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_7 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_8 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_9 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_10 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -3
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_11 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 2
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -3
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_12 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -3
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 2
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_13 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_14 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 2
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_15 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -3
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 3
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_16 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_17 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 3
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -3
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_18 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 3
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_19 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 3
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 3
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_20 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 2
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 3
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_21 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -2
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -3
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 2
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_22 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_23 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 3
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_24 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 2
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_25 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -3
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_26 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 3
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 2
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -3
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_27 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -3
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_28 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -3
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -2
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_29 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 3
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_30 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -2
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 3
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 -2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 3
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_31 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_32 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_33 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 3
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -2
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_34 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 2
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -3
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_35 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 3
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -2
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -3
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 -2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -3
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_36 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -3
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -2
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -2
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_37 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -3
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 2
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_38 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 3
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -2
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_39 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 3
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -3
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_40 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -3
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -3
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 2
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -3
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_41 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 3
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -2
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_42 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 3
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_43 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -3
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_44 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 3
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 -3
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -2
# ...
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_86 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -3
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 -2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 3
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_87 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -3
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 3
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -3
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_88 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -2
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_89 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 3
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -3
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -3
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 2
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 3
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 2
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_90 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -3
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 -2
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_91 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 3
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 2
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_92 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 -3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -2
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 -3
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -2
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 3
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_93 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 2
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -3
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -2
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 3
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 -3
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 -3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_94 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 2
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -3
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -2
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -3
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 2
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 -2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_95 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -2
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 3
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 2
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -3
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 -2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 -3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_96 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-03 00:00:00 RBL8 3599.0 2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 -3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 -2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 3
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -2
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 -2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 3
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -2
# QAACCOUNT ==> receive deal 2020-01-07 00:00:00 RBL8 3574.0 3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_97 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-02 00:00:00 RBL8 3634.0 -2
# QAACCOUNT ==> receive deal 2019-12-05 00:00:00 RBL8 3585.0 3
# QAACCOUNT ==> receive deal 2019-12-06 00:00:00 RBL8 3437.0 2
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 -3
# QAACCOUNT ==> receive deal 2019-12-10 00:00:00 RBL8 3505.0 2
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 -3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 2
# QAACCOUNT ==> receive deal 2019-12-13 00:00:00 RBL8 3523.0 -3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -2
# QAACCOUNT ==> receive deal 2019-12-27 00:00:00 RBL8 3541.0 3
# QAACCOUNT ==> receive deal 2019-12-30 00:00:00 RBL8 3545.0 -2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 -2
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 3
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_98 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-09 00:00:00 RBL8 3511.0 2
# QAACCOUNT ==> receive deal 2019-12-19 00:00:00 RBL8 3518.0 -3
# QAACCOUNT ==> receive deal 2019-12-20 00:00:00 RBL8 3507.0 -2
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 3
# QAACCOUNT ==> receive deal 2019-12-24 00:00:00 RBL8 3510.0 2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 -3
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 -2
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 3
# QAACCOUNT ==> receive deal 2020-01-08 00:00:00 RBL8 3617.0 -2
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 3
# QAACCOUNT ==> receive deal 2020-01-10 00:00:00 RBL8 3571.0 2
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# < QA_Account ac_99 market: future_cn>
# QAACCOUNT ==> receive deal 2019-12-04 00:00:00 RBL8 3603.0 -2
# QAACCOUNT ==> receive deal 2019-12-11 00:00:00 RBL8 3537.0 3
# QAACCOUNT ==> receive deal 2019-12-12 00:00:00 RBL8 3524.0 -2
# QAACCOUNT ==> receive deal 2019-12-16 00:00:00 RBL8 3480.0 3
# QAACCOUNT ==> receive deal 2019-12-17 00:00:00 RBL8 3484.0 -2
# QAACCOUNT ==> receive deal 2019-12-18 00:00:00 RBL8 3476.0 3
# QAACCOUNT ==> receive deal 2019-12-23 00:00:00 RBL8 3538.0 -2
# QAACCOUNT ==> receive deal 2019-12-25 00:00:00 RBL8 3485.0 3
# QAACCOUNT ==> receive deal 2019-12-26 00:00:00 RBL8 3529.0 -2
# QAACCOUNT ==> receive deal 2019-12-31 00:00:00 RBL8 3569.0 3
# QAACCOUNT ==> receive deal 2020-01-02 00:00:00 RBL8 3547.0 2
# QAACCOUNT ==> receive deal 2020-01-06 00:00:00 RBL8 3559.0 -3
# QAACCOUNT ==> receive deal 2020-01-09 00:00:00 RBL8 3555.0 -2

# %%
port
# Out:
# < QA_Portfolio test_newAccounts2 with 100 Accounts >

# %%
holdP = port.hold_table('2020-01-05')
holdP
# Out:
#                      amount
# code account_cookie
# RBL8 ac_0                 0
#      ac_1                 1
#      ac_10                0
#      ac_11               -1
#      ac_12               -1
#      ac_13                1
#      ac_14                1
#      ac_15                1
#      ac_16               -1
#      ac_17                0
#      ac_18               -1
#      ac_19                0
#      ac_2                 1
#      ac_20                1
#      ac_21                1
#      ac_22                1
#      ac_23                0
#      ac_24                0
#      ac_25                0
#      ac_26               -1
#      ac_27                0
#      ac_28                1
#      ac_29               -1
#      ac_3                 0
#      ac_30                0
#      ac_31                0
#      ac_32                1
#      ac_33               -1
#      ac_34                1
#      ac_35                1
# ...                     ...
#      ac_72                0
#      ac_73                0
#      ac_74                0
#      ac_75               -1
#      ac_76                1
#      ac_77               -1
#      ac_78               -1
#      ac_79                1
#      ac_8                -1
#      ac_80                0
#      ac_81                0
#      ac_82                0
#      ac_83                0
#      ac_84                1
#      ac_85                1
#      ac_86                0
#      ac_87                0
#      ac_88                0
#      ac_89                0
#      ac_9                 0
#      ac_90                0
#      ac_91                0
#      ac_92               -1
#      ac_93                0
#      ac_94                0
#      ac_95               -1
#      ac_96                0
#      ac_97               -1
#      ac_98                0
#      ac_99                1
#
# [100 rows x 1 columns]

# %%
holdP.sum()
# Out:
# amount    5
# dtype: int64

# %%
holdP.describe()
# Out:
#            amount
# count  100.000000
# mean     0.050000
# std      0.729951
# min     -1.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
holdP.plot.bar()
