# %%
import tushare
import requests
import json
import lxml
import time,datetime

## 查询当日委托
print(requests.get('http://localhost:8888/orders').text)
# Out:
# {"count":0,"dataTable":{"columns":["委托时间","证券代码","证券名称","买卖标志","状态说明","委托价格","委托数量","委托编号","成交价格","成交数量","报价方式","股东代码"],"rows":[["没有相应的查询信息!","","","","","","","","","","",""]]},"startDate":0,"endDate":0}

# %%
requests.delete('http://localhost:8888/orders')
# Out:
# <Response [200]>

# %%
print(requests.get('http://localhost:8888/orders').text)
# Out:
# {"count":132,"dataTable":{"columns":["委托时间","证券代码","证券名称","买卖标志","状态说明","委托价格","委托数量","委托编号","成交价格","成交数量","报价方式","股东代码"],"rows":[["10:18:42","000001","平安银行","买入","废单","3.000","100.00","375","0","0","委托","0200188059"],["10:19:51","000001","平安银行","买入","废单","3.000","100.00","379","0","0","委托","0200188059"],["10:19:52","000001","平安银行","买入","废单","3.000","100.00","380","0","0","委托","0200188059"],["10:19:53","000001","平安银行","买入","废单","3.000","100.00","381","0","0","委托","0200188059"],["10:19:54","000001","平安银行","买入","废单","3.000","100.00","382","0","0","委托","0200188059"],["10:19:55","000001","平安银行","买入","废单","3.000","100.00","383","0","0","委托","0200188059"],["10:19:56","000001","平安银行","买入","废单","3.000","100.00","384","0","0","委托","0200188059"],["10:19:56","000001","平安银行","买入","废单","3.000","100.00","385","0","0","委托","0200188059"],["10:19:57","000001","平安银行","买入","废单","3.000","100.00","386","0","0","委托","0200188059"],["10:19:58","000001","平安银行","买入","废单","3.000","100.00","387","0","0","委托","0
# ...

# %%
## 查询当日成交
#GET http://localhost:8888/orders?status=filled

for i in range(0,100,1):
    print(requests.post('http://localhost:8888/orders',data=json.dumps( {
            "action": "BUY",
            "symbol" : "000001",
            "type": "LIMIT",
            "priceType" : 0,
            "price" : 3.00,
            "amount" : 100
        }
    )))
    time.sleep(0.5)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ...

# %%
## 查询投资组合
print(requests.get('http://localhost:8888/positions').text)
# Out:
# {"subAccounts":{"人民币":{"余额":10000,"参考市值":0,"可用":10000,"盈亏":0,"资产":10000}},"count":0,"dataTable":{"columns":["证券代码","证券名称","证券数量","可卖数量","成本价","当前价","最新市值","浮动盈亏","盈亏比例(%)","股东代码"],"rows":[["没有相应的查询信息!","","","","","","","","",""]]},"startDate":0,"endDate":0}

# %%
print(requests.post('http://localhost:8888/orders',data=json.dumps( {
            "action": "BUY",
            "symbol" : "000001",
            "type": "LIMIT",
            "priceType" : 0,
            "price" : 8.00,
            "amount" : 100
        }
    )))
# Out:
# <Response [200]>

# %%
print(requests.get('http://localhost:8888/orders').text)
# Out:
# {"count":155,"dataTable":{"columns":["委托时间","证券代码","证券名称","买卖标志","状态说明","委托价格","委托数量","委托编号","成交价格","成交数量","报价方式","股东代码"],"rows":[["10:18:42","000001","平安银行","买入","废单","3.000","100.00","375","0","0","委托","0200188059"],["10:19:51","000001","平安银行","买入","废单","3.000","100.00","379","0","0","委托","0200188059"],["10:19:52","000001","平安银行","买入","废单","3.000","100.00","380","0","0","委托","0200188059"],["10:19:53","000001","平安银行","买入","废单","3.000","100.00","381","0","0","委托","0200188059"],["10:19:54","000001","平安银行","买入","废单","3.000","100.00","382","0","0","委托","0200188059"],["10:19:55","000001","平安银行","买入","废单","3.000","100.00","383","0","0","委托","0200188059"],["10:19:56","000001","平安银行","买入","废单","3.000","100.00","384","0","0","委托","0200188059"],["10:19:56","000001","平安银行","买入","废单","3.000","100.00","385","0","0","委托","0200188059"],["10:19:57","000001","平安银行","买入","废单","3.000","100.00","386","0","0","委托","0200188059"],["10:19:58","000001","平安银行","买入","废单","3.000","100.00","387","0","0","委托","0
# ...

# %%
#下单+撤单  
for i in range(0,10,1):
    print(i)
    print(requests.post('http://localhost:8888/orders',data=json.dumps( {
                "action": "BUY",#卖出是sell
                "symbol" : "000001",
                "type": "LIMIT",#限价单
                "priceType" : 0,
                "price" : 8.00,
                "amount" : 100
            }
        )))
    time.sleep(1)

requests.delete('http://localhost:8888/orders')
""""
type 可选择：
* LIMIT - 限价单，需指定 price
* MARKET - 市价单，需指定 priceType（非 0）

priceType 可选择：
上海交易所：
* 0 - 限价委托
* 4 - 五档即时成交剩余撤销
* 6 - 五档即时成交剩余转限

深圳交易所：
* 0 - 限价委托
* 1 - 对手方最优价格委托
* 2 - 本方最优价格委托
* 3 - 即时成交剩余撤销委托
* 4 - 五档即时成交剩余撤销
* 5 - 全额成交或撤销委托
"""
# Out:
# 0
# <Response [200]>
# 1
# <Response [200]>
# 2
# <Response [200]>
# 3
# <Response [200]>
# 4
# <Response [200]>
# 5
# <Response [200]>
# 6
# <Response [200]>
# 7
# <Response [200]>
# 8
# <Response [200]>
# 9
# <Response [200]>
# '"\ntype 可选择：\n* LIMIT - 限价单，需指定 price\n* MARKET - 市价单，需指定 priceType（非 0）\n\npriceType 可选择：\n上海交易所：\n* 0 - 限价委托\n* 4 - 五档即时成交剩余撤销\n* 6 - 五档即时成交剩余转限\n\n深圳交易所：\n* 0 - 限价委托\n* 1 - 对手方最优价格委托\n* 2 - 本方最优价格委托\n* 3 - 即时成交剩余撤销委托\n* 4 - 五档即时成交剩余撤销\n* 5 - 全额成交或撤销委托\n'

# %%
requests.delete('http://localhost:8888/orders')
# Out:
# <Response [200]>
