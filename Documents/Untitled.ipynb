# %%
import QUANTAXIS as QA
# Out:
# QUANTAXIS>> start QUANTAXIS
# QUANTAXIS>> Expand macros in C:\Users\yhh\Anaconda3\lib\site-packages\macropy\core\hquotes.py
# QUANTAXIS>> Finding macros in 'macropy.core.hquotes'
# QUANTAXIS>> Importing macros from 'macropy.core.quotes' into 'macropy.core.hquotes'
# QUANTAXIS>> Expand macros in C:\Users\yhh\Anaconda3\lib\site-packages\macropy\core\quotes.py
# QUANTAXIS>> Finding macros in 'macropy.core.quotes'
# QUANTAXIS>> Expand macros in C:\Users\yhh\Anaconda3\lib\site-packages\macropy\core\failure.py
# QUANTAXIS>> Finding macros in 'macropy.core.failure'
# QUANTAXIS>> Importing macros from 'macropy.core.hquotes' into 'macropy.core.failure'
# QUANTAXIS>> Expand macros in C:\Users\yhh\Anaconda3\lib\site-packages\cffi\api.py
# QUANTAXIS>> Finding macros in 'cffi.api'
# QUANTAXIS>> Expand macros in C:\Users\yhh\Anaconda3\lib\site-packages\scipy\__config__.py
# QUANTAXIS>> Finding macros in 'scipy.__config__'
# QUANTAXIS>> Welcome to QUANTAXIS, the Version is 1.0.69.dev3
# ...

# %%
account_info=QA.QA_fetch_account({'account_cookie':'0.08_offset0hold0'})
Account=QA.QA_Account().from_message(account_info[0])
Performance=QA.QA_Performance(Account)
# Out:
# C:\Users\yhh\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: QUANTAXIS 1.0.46 has changed the init_assets ==> init_cash, please pay attention to this change if you using init_cash to initial an account class,

# %%
Performance.plot_pnlmoney(Performance.pnl_fifo)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\yhh\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Risk=QA.QA_Risk(Account)

# %%
Performance.pnl_fifo.sort_values('buy_date')[15:30]
# Out:
#                  sell_date            buy_date  amount  sell_price  buy_price  \
# code
# 000026 2017-09-15 15:00:00 2017-08-08 15:00:00  4100.0       11.58      11.11
# 000035 2018-07-11 15:00:00 2017-08-08 15:00:00  7000.0        4.91       6.55
# 000028 2017-08-25 15:00:00 2017-08-14 15:00:00   500.0       70.52      77.06
# 000040 2017-09-15 15:00:00 2017-08-15 15:00:00  3000.0       14.61      13.22
# 000001 2017-09-13 15:00:00 2017-08-28 15:00:00  3100.0       11.25      11.17
# 000059 2017-09-19 15:00:00 2017-09-13 15:00:00  2900.0       11.44      12.00
# 000012 2017-09-25 15:00:00 2017-09-15 15:00:00  6000.0        7.20       7.56
# 000056 2017-09-25 15:00:00 2017-09-15 15:00:00  3600.0       12.08      12.60
# 000028 2017-11-01 15:00:00 2017-09-19 15:00:00   500.0       66.71      67.22
# 000037 2017-09-27 15:00:00 2017-09-25 15:00:00  4900.0        8.73       8.86
# 000063 2017-10-23 15:00:00 2017-09-25 15:00:00  1600.0       28.49      26.25
# ...

# %%
# Risk.plot_signal()

# %%
Performance.pnl_fifo.sort_values('buy_date')[0:15]
# Out:
#                  sell_date            buy_date  amount  sell_price  buy_price  \
# code
# 000035 2017-06-26 15:00:00 2017-06-01 15:00:00  6000.0        6.82       6.65
# 000088 2017-06-26 15:00:00 2017-06-01 15:00:00  4100.0       10.81       9.55
# 000018 2017-07-03 15:00:00 2017-06-01 15:00:00  5600.0        7.55       7.14
# 000009 2017-07-17 15:00:00 2017-06-02 15:00:00  5500.0        7.51       7.28
# 000031 2017-07-18 15:00:00 2017-06-02 15:00:00  5600.0        7.11       7.23
# 000036 2017-07-10 15:00:00 2017-06-27 15:00:00  5200.0        8.19       8.16
# 000035 2017-07-14 15:00:00 2017-06-27 15:00:00  6200.0        6.81       6.86
# 000056 2017-08-10 15:00:00 2017-07-03 15:00:00  3400.0       12.46      12.20
# 000078 2017-07-18 15:00:00 2017-07-10 15:00:00  6900.0        6.01       6.27
# 000036 2017-08-07 15:00:00 2017-07-17 15:00:00  4900.0       10.80       8.48
# 000008 2017-08-04 15:00:00 2017-07-20 15:00:00  3600.0        7.43       7.47
# ...

# %%
print(int(9694.72))
