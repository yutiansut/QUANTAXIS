# %% [markdown]
# from bs4 import BeautifulSoup
# path='E:/test/1.html'
# htmlfile = open(path, 'r', encoding='utf-8')
# htmlhandle = htmlfile.read()
# soup = BeautifulSoup(htmlhandle, 'lxml')
# tab= soup.findAll('table',style="border-collapse:collapse;width:19cm;")
# trs = tab[0].findAll('tr')
# print(trs[1])

# %%
from bs4 import BeautifulSoup 
path='E:/test/1.html' 
htmlfile = open(path, 'r', encoding='utf-8') 
htmlhandle = htmlfile.read() 
soup = BeautifulSoup(htmlhandle, 'lxml') 
tab= soup.findAll('table',style="border-collapse:collapse;width:19cm;") 
trs = tab[0].findAll('tr')
min_salary_rows=[]
min_salary=[]
def earse(strline,ch) :  
   # left = 0  
    right = strline.find(ch)  

    while right !=-1 :  
            #print 66666666666666666667
            strline = strline.replace(ch,'') 
            #print 6777777777777 
            right = strline.find(ch)  
            #print 8989888888888888
    return strline 
f = open('aa.txt', 'w')
b=0
min_salary_rows=[]
jgmc=0
sl=0
print(len(trs))
for trIter in trs :  
                a=0
                tds = trIter.findAll('td')  
                for tdIter in tds :  
                        p = tdIter('span')  
                        for i in range(len(p)) :  
                                if p[i].string :  
                                    min_salary_rows.append((earse(p[i].string,' ').strip()))
                                    f.write(earse(p[i].string,' ').strip());
                                    #print (earse(p[i].string,' ').strip().replace(',', '')), 
                                    c=earse(p[i].string,' ').strip()
                                    #print a
                                    #print b
                                    if a == 0 and b>= 6:
                                        V_JGMC=earse(p[i].string,' ').strip().replace(',', '')
                                    if a == 1 and b>= 6:
                                        N_BR_YE=earse(p[i].string,' ').strip().replace(',', '')
                                    if a == 2 and b>= 6:
                                        V_BR_MC=earse(p[i].string,' ').strip().replace(',', '')
                                    if a == 3 and b>= 6:
                                        N_BR_XZYE=earse(p[i].string,' ').strip().replace(',', '')
                                    if a == 4 and b>= 6:
                                        N_BX_XZYE=earse(p[i].string,' ').strip().replace(',', '')
                                    if a == 5 and b>= 6:
                                        N_BY_XZYE=earse(p[i].string,' ').strip().replace(',', '')
                                    if a == 6 and b>= 6:
                                        N_BN_XZYE=earse(p[i].string,' ').strip().replace(',', '')
                                    if a == 7 and b>= 6:
                                        V_BN_YEMC=earse(p[i].string,' ').strip().replace(',', '')
                                    if a == 8 and b>= 6:
                                        V_BN_XZFD=earse(p[i].string,' ').strip().replace(',', '') 
                                    # if a == 9 and b>= 7 and zl == 1:
                                    #     V_BN_FDMC=earse(p[i].string,' ').strip().replace(',', '')                   
                                    #     cursor.execute ("INSERT INTO TEMP_YE_ZZQK (V_JGMC, N_BR_YE,V_BR_MC,N_BR_XZYE,N_BX_XZYE,N_BY_XZYE,N_BN_XZYE,V_BN_YEMC,V_BN_XZFD,V_BN_FDMC,D_RQ,C_JGJB,N_LSH)\
                                    #     VALUES('"+V_JGMC+"','"+N_BR_YE+"','"+V_BR_MC+"','"+N_BR_XZYE+"','"+N_BX_XZYE+"','"+N_BY_XZYE+"','"+N_BN_XZYE+"','"+V_BN_YEMC+"','"+V_BN_XZFD+"','"+V_BN_FDMC+"',to_date('"+year+""+mouth+""+day+"','yyyymmdd'),'2','1')") 
                                        #cursor.execute ("INSERT INTO TEMP_YE_ZLTJ (V_JGMC,N_BQYE,D_RQ,N_LSH)VALUES('"+V_JGMC+"','"+N_BQYE+"',to_date('20180226','yyyymmdd'),'1')")  
                                    # if a == 9 and b>= 7 and zl == 2:
                                    #     V_BN_FDMC=earse(p[i].string,' ').strip().replace(',', '')                   
                                    #     cursor.execute ("INSERT INTO TEMP_YE_ZZQK (V_JGMC, N_BR_YE,V_BR_MC,N_BR_XZYE,N_BX_XZYE,N_BY_XZYE,N_BN_XZYE,V_BN_YEMC,V_BN_XZFD,V_BN_FDMC,D_RQ,C_JGJB,N_LSH)\
                                    #     VALUES('"+V_JGMC+"','"+N_BR_YE+"','"+V_BR_MC+"','"+N_BR_XZYE+"','"+N_BX_XZYE+"','"+N_BY_XZYE+"','"+N_BN_XZYE+"','"+V_BN_YEMC+"','"+V_BN_XZFD+"','"+V_BN_FDMC+"',to_date('"+year+""+mouth+""+day+"','yyyymmdd'),'3','1')") 
                                        #cursor.e
                                    #if a == 9 and b>= 7 and zl >= 3 and zl <=10:
                                    

                                    if a == 9 and b>= 6:
                                        V_BN_FDMC=earse(p[i].string,' ').strip().replace(',', '')
                                        print ("19910199101991")                   
                                        cursor.execute ("INSERT INTO TEMP_YE_ZZQK (V_JGMC, N_BR_YE,V_BR_MC,N_BR_XZYE,N_BX_XZYE,N_BY_XZYE,N_BN_XZYE,V_BN_YEMC,V_BN_XZFD,V_BN_FDMC,D_RQ,C_JGJB,C_ZT,N_LSH)\
                                        VALUES('"+V_JGMC+"','"+N_BR_YE+"','"+V_BR_MC+"','"+N_BR_XZYE+"','"+N_BX_XZYE+"','"+N_BY_XZYE+"','"+N_BN_XZYE+"','"+V_BN_YEMC+"','"+V_BN_XZFD+"','"+V_BN_FDMC+"',to_date('"+year+""+mouth+""+day+"','yyyymmdd'),'5','0','1')") 
                                        print ("19910199101991")

                                        #cursor.e
                                    # if a == 9 and b>= 7 and zl >= 11 and zl <=19:
                                    #     V_BN_FDMC=earse(p[i].string,' ').strip().replace(',', '')                   
                                    #     cursor.execute ("INSERT INTO TEMP_YE_ZZQK (V_JGMC, N_BR_YE,V_BR_MC,N_BR_XZYE,N_BX_XZYE,N_BY_XZYE,N_BN_XZYE,V_BN_YEMC,V_BN_XZFD,V_BN_FDMC,D_RQ,C_JGJB,N_LSH)\
                                    #     VALUES('"+V_JGMC+"','"+N_BR_YE+"','"+V_BR_MC+"','"+N_BR_XZYE+"','"+N_BX_XZYE+"','"+N_BY_XZYE+"','"+N_BN_XZYE+"','"+V_BN_YEMC+"','"+V_BN_XZFD+"','"+V_BN_FDMC+"',to_date('"+year+""+mouth+""+day+"','yyyymmdd'),'3','1')") 
                                        #cursor.e
                                    # if a == 9 and zl == 20:
                                    #     V_BN_FDMC=earse(p[i].string,' ').strip().replace(',', '')                   
                                    #     cursor.execute ("INSERT INTO TEMP_YE_ZZQK (V_JGMC, N_BR_YE,V_BR_MC,N_BR_XZYE,N_BX_XZYE,N_BY_XZYE,N_BN_XZYE,V_BN_YEMC,V_BN_XZFD,V_BN_FDMC,D_RQ,C_JGJB,N_LSH)\
                                    #     VALUES('"+V_JGMC+"','"+N_BR_YE+"','"+V_BR_MC+"','"+N_BR_XZYE+"','"+N_BX_XZYE+"','"+N_BY_XZYE+"','"+N_BN_XZYE+"','"+V_BN_YEMC+"','"+V_BN_XZFD+"','"+V_BN_FDMC+"',to_date('"+year+""+mouth+""+day+"','yyyymmdd'),'1','1')") 
                                        #cursor.e
                                        #cursor.execute ("INSERT INTO TEMP_YE_ZLTJ (V_JGMC,N_BQYE,D_RQ,N_LSH)VALUES('"+V_JGMC+"','"+N_BQYE+"',to_date('20180226','yyyymmdd'),'1')")  
                                        a=a+1   
                                    else :  
                                            pass  
                                min_salary.append(min_salary_rows)        
                        b=b+1 
                        # print
       
            
         
        
print(trs[5])
# Out:
# 79
# ...
